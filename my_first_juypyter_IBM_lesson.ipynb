# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# **Yasuo Shiokawa**
#
# My Job: mechanical engineer

# %% [markdown]
# *I am interested in data science, because data science can solve a lot of problems in this world.*
#
# *I would like to increase the amount of data that can be manipulated and processed, thereby increasing the amount of knowledge that can be gained.*
#
# I can't loggin the IBM Watson.So Using jupyter noteboook.

# %% [markdown]
# ### Drawing $$y = 2x^2$$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(51)
y = 2 * x ** 2
plt.plot(x, y)
plt.show()

# %% [markdown]
# **Comment**
#
# ~I want to drink a beer.~
#
# <font color="red">test red</font>
# **<font color="red">test red</font>**
#
# >Boys and girls be ambitious!!
#
# How to make yakisoba
# 1. Prepare vegitables
#   1. cut cabbage into chunks
#   2. cut carrot into small pieces
#   3. prepare bean sprouts
#
# 2. Prepare meat
#   Pork belly is good. Thickness is up to you
#
# 3. Put oil in a lrying pan and fry the meat.
# 4. Add salt and pepper
# 5. Fry begetables
# 6. stir-fry the noodles
# 7. Add sauce and stir-fry
# 8. Ready to serve, Eat while hot
#
# >sample recipe
# https://www.otafuku.co.jp/recipe/cook/noodle/nood01.html
#
#
#
# | hungry  | full  |
# |-----------|------ |
# | Eat      |  Sleep|
